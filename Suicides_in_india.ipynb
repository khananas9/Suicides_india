# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as po
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# #### Load Data

# %%
# To load the data 

df=pd.read_csv('d:/Ducat/PROJECTS/Indian Sucide cases/Suicides in India 2001-2012.csv')

# %%
df
# Out:
#                 State  Year      Type_code  \
# 0       A & N Islands  2001         Causes
# 1       A & N Islands  2001         Causes
# 2       A & N Islands  2001         Causes
# 3       A & N Islands  2001         Causes
# 4       A & N Islands  2001         Causes
# ...               ...   ...            ...
# 237514    West Bengal  2012  Social_Status
# 237515    West Bengal  2012  Social_Status
# 237516    West Bengal  2012  Social_Status
# 237517    West Bengal  2012  Social_Status
# 237518    West Bengal  2012  Social_Status
#
#                                            Type  Gender Age_group  Total
# 0                            Illness (Aids/STD)  Female      0-14      0
# 1       Bankruptcy or Sudden change in Economic  Female      0-14      0
# 2       Cancellation/Non-Settlement of Marriage  Female      0-14      0
# 3             Physical Abuse (Rape/Incest Etc.)  Female      0-14      0
# 4                                 Dowry Dispute  Female      0-14      0
# ...

# %%
# Number of Rows and Column in dataset

print('Total number of rows in this Dataset are ',df.shape[0])
print('Total number of columns in this data set are ',df.shape[1])
# Out:
# Total number of rows in this Dataset are  237519
# Total number of columns in this data set are  7

# %%
# Dataset information

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237519 entries, 0 to 237518
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   State      237519 non-null  object
#  1   Year       237519 non-null  int64
#  2   Type_code  237519 non-null  object
#  3   Type       237519 non-null  object
#  4   Gender     237519 non-null  object
#  5   Age_group  237519 non-null  object
#  6   Total      237519 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 12.7+ MB
# None

# %%
# to get the name of columns in dataset
print(df.columns)
# Out:
# Index(['State', 'Year', 'Type_code', 'Type', 'Gender', 'Age_group', 'Total'], dtype='object')

# %%
# To get the unique valuse from the column state

df.State.unique()
# Out:
# array(['A & N Islands', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam',
#        'Bihar', 'Chandigarh', 'Chhattisgarh', 'D & N Haveli',
#        'Daman & Diu', 'Delhi (Ut)', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha',
#        'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Total (All India)', 'Total (States)', 'Total (Uts)', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal'], dtype=object)

# %% [markdown]
# #### Checking distinct values in each column

# %%
df[['Year','Total']].groupby('Year',as_index=False).sum()
# Out:
#     Year    Total
# 0   2001   976464
# 1   2002   993648
# 2   2003   997622
# 3   2004  1023137
# 4   2005  1025201
# 5   2006  1062991
# 6   2007  1103667
# 7   2008  1125082
# 8   2009  1144033
# 9   2010  1211322
# 10  2011  1219499
# 11  2012  1189068

# %%
df.Age_group.value_counts()
# Out:
# Age_group
# 15-29     45223
# 30-44     45193
# 45-59     45146
# 60+       45074
# 0-14      45027
# 0-100+    11856
# Name: count, dtype: int64

# %%
# To know the unique values in type_code column

print(df.Type_code.unique())
# Out:
# ['Causes' 'Education_Status' 'Means_adopted' 'Professional_Profile'
#  'Social_Status']

# %%
# To get the value counts of type_code columns

print(df.Type_code.value_counts())
# Out:
# Type_code
# Causes                  109200
# Means_adopted            67200
# Professional_Profile     49263
# Education_Status          7296
# Social_Status             4560
# Name: count, dtype: int64

# %%
# To get all the distinct means adopted 

df[df['Type_code']=='Means_adopted'].Type.value_counts()
# Out:
# Type
# By Consuming Insecticides                  4200
# By Over Alcoholism                         4200
# By Fire-Arms                               4200
# By Drowning                                4200
# By Jumping from (Building)                 4200
# By Overdose of sleeping pills              4200
# By coming under running vehicles/trains    4200
# By Consuming Other Poison                  4200
# By Self Infliction of injury               4200
# By Hanging                                 4200
# By Jumping off Moving Vehicles/Trains      4200
# By Fire/Self Immolation                    4200
# By Machine                                 4200
# By touching electric wires                 4200
# By Jumping from (Other sites)              4200
# By Other means (please specify)            3850
# By Other means                              350
# Name: count, dtype: int64

# %%
# Professions

df[df['Type_code']=='Professional_Profile'].Type.value_counts()
# Out:
# Type
# Others (Please Specify)              7263
# Retired Person                       4200
# Unemployed                           4200
# Public Sector Undertaking            4200
# Service (Private)                    4200
# House Wife                           4200
# Self-employed (Business activity)    4200
# Professional Activity                4200
# Student                              4200
# Farming/Agriculture Activity         4200
# Service (Government)                 4200
# Name: count, dtype: int64

# %%
# Education status

df[df['Type_code']=='Education_Status'].Type.value_counts()
# Out:
# Type
# Diploma                                     912
# No Education                                912
# Post Graduate and Above                     912
# Middle                                      912
# Graduate                                    912
# Hr. Secondary/Intermediate/Pre-Universit    912
# Primary                                     912
# Matriculate/Secondary                       912
# Name: count, dtype: int64

# %%
# Social Status

df[df['Type_code']=='Social_Status'].Type.value_counts()
# Out:
# Type
# Married            912
# Seperated          912
# Widowed/Widower    912
# Divorcee           912
# Never Married      912
# Name: count, dtype: int64

# %% [markdown]
# #### Data Pre-Processing

# %%
# To check if there is any null values 

df.isnull().sum()
# Out:
# State        0
# Year         0
# Type_code    0
# Type         0
# Gender       0
# Age_group    0
# Total        0
# dtype: int64

# %% [markdown]
# #### --> There is no null values in dataset

# %%
df.State.value_counts()
# Out:
# State
# Madhya Pradesh       6792
# Maharashtra          6792
# Karnataka            6792
# Odisha               6791
# Andhra Pradesh       6791
# Rajasthan            6791
# Bihar                6790
# Chhattisgarh         6790
# Haryana              6790
# Kerala               6788
# Uttar Pradesh        6787
# Assam                6786
# Tamil Nadu           6786
# Gujarat              6786
# Jharkhand            6785
# Tripura              6782
# Delhi (Ut)           6782
# West Bengal          6780
# Punjab               6779
# Himachal Pradesh     6774
# Jammu & Kashmir      6761
# Goa                  6759
# Uttarakhand          6758
# Sikkim               6742
# Mizoram              6737
# Meghalaya            6733
# Puducherry           6730
# Chandigarh           6717
# A & N Islands        6712
# Daman & Diu          6710
# Arunachal Pradesh    6707
# Nagaland             6705
# D & N Haveli         6704
# Manipur              6700
# Lakshadweep          6674
# ...

# %% [markdown]
# #### > We can see values like Total (All India), Total (States), Total (Uts), Before moviong forward these values needs to be removed.

# %%
# Removing unwanted Values

df=df[(df['State']!='Total (All India)') & (df['State']!='Total (States)') & (df['State']!='Total (Uts)')]

# %%
df.State.value_counts()
# Out:
# State
# Karnataka            6792
# Madhya Pradesh       6792
# Maharashtra          6792
# Andhra Pradesh       6791
# Odisha               6791
# Rajasthan            6791
# Chhattisgarh         6790
# Bihar                6790
# Haryana              6790
# Kerala               6788
# Uttar Pradesh        6787
# Tamil Nadu           6786
# Gujarat              6786
# Assam                6786
# Jharkhand            6785
# Tripura              6782
# Delhi (Ut)           6782
# West Bengal          6780
# Punjab               6779
# Himachal Pradesh     6774
# Jammu & Kashmir      6761
# Goa                  6759
# Uttarakhand          6758
# Sikkim               6742
# Mizoram              6737
# Meghalaya            6733
# Puducherry           6730
# Chandigarh           6717
# A & N Islands        6712
# Daman & Diu          6710
# Arunachal Pradesh    6707
# Nagaland             6705
# D & N Haveli         6704
# Manipur              6700
# Lakshadweep          6674
# ...

# %% [markdown]
# #### Data Visualization

# %% [markdown]
# #### Yearwise suicide cases

# %%
df.head()
causes=df[df['Type_code']=='Causes']

# %%
causes.groupby(by='Year')['Total'].sum().index
# Out:
# Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012], dtype='int64', name='Year')

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x=causes.groupby(by='Year')['Total'].sum().index,
             y=causes.groupby(by='Year')['Total'].sum())
sns.set_style(style='darkgrid')
plt.title('Year wise number of suicide in India',fontsize=12)
plt.ylabel('Suicide Cases')

plt.show()

# %% [markdown]
# #### Statewise suicide cases

# %%
#causes.head()
plt.figure(figsize=(8,6))
state=df.groupby('State',as_index=False)[['Total']].sum()
Top_state=state.sort_values(by='Total',ascending=False).head(15)
sns.barplot(data=Top_state,x='Total',y='State',palette='Reds_r')
plt.xticks(size=8)
plt.yticks(size=8)
plt.title('State wise suicide cases (Top 15) ')
plt.show()

# %% [markdown]
# ####  > These are the top States where most of the sucide takes place. Maharashtra tops

# %%
plt.figure(figsize=(8, 6))
state = df.groupby('State', as_index=False)[['Total']].sum()
low = state.sort_values(by='Total', ascending=True).head(5)
sns.barplot(data=low, x='State', y='Total', palette='Blues')
plt.title('States with Lowest suicides recorded')

plt.show()

# %%
why=causes.groupby('Type',as_index=False)['Total'].sum()
top_t=why.sort_values(by='Total',ascending=False)
top_t.style.background_gradient(subset='Total',cmap='Reds')
# Out:
# <style type="text/css">
# #T_77485_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_77485_row1_col1 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_77485_row2_col1 {
#   background-color: #ed392b;
#   color: #f1f1f1;
# }
# #T_77485_row3_col1 {
#   background-color: #f4503a;
#   color: #f1f1f1;
# }
# #T_77485_row4_col1 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_77485_row5_col1 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_77485_row6_col1 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_77485_row7_col1, #T_77485_row8_col1 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_77485_row9_col1 {
#   background-color: #fee7dc;
#   color: #000000;
# }
# #T_77485_row10_col1, #T_77485_row11_col1 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_77485_row12_col1 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_77485_row13_col1 {
#   background-color: #ffeee7;
# ...

# %%
plt.figure(figsize=(12,10))
sns.barplot(data=top_t,x='Total',y='Type')
plt.title('Major Reasons why people commited suicide')
plt.tight_layout()
plt.show()

# %%
df.Type_code.unique()
# Out:
# array(['Causes', 'Education_Status', 'Means_adopted',
#        'Professional_Profile', 'Social_Status'], dtype=object)

# %%
Education=df[df['Type_code']=='Education_Status']
cause=df[df['Type_code']=='Causes']
means=df[df['Type_code']=='Means_adopted']
profession=df[df['Type_code']=='Professional_Profile']
social=df[df['Type_code']=='Social_Status']

# %%
Ed=Education.groupby(by=['Type','Gender'],as_index=False)[['Total']].sum().sort_values('Total',ascending=False)
Ed.style.background_gradient(subset='Total',cmap='Reds')
# Out:
# <style type="text/css">
# #T_c1f94_row0_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_c1f94_row1_col2 {
#   background-color: #69000d;
#   color: #f1f1f1;
# }
# #T_c1f94_row2_col2 {
#   background-color: #b11218;
#   color: #f1f1f1;
# }
# #T_c1f94_row3_col2 {
#   background-color: #c5171c;
#   color: #f1f1f1;
# }
# #T_c1f94_row4_col2 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_c1f94_row5_col2 {
#   background-color: #f34a36;
#   color: #f1f1f1;
# }
# #T_c1f94_row6_col2 {
#   background-color: #fa6547;
#   color: #f1f1f1;
# }
# #T_c1f94_row7_col2 {
#   background-color: #fc9879;
#   color: #000000;
# }
# #T_c1f94_row8_col2 {
#   background-color: #fc9c7d;
#   color: #000000;
# }
# #T_c1f94_row9_col2 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_c1f94_row10_col2 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_c1f94_row11_col2 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_c1f94_row12_col2 {
# ...

# %%
plt.figure(figsize=(13,6))
Ed=Education.groupby(by=['Type','Gender'],as_index=False)[['Total']].sum().sort_values('Total',ascending=False)
sns.barplot(data=Ed,x='Type',y='Total',hue='Gender',width=.7)
plt.title('Gender Wise Education Level of People who Committed Suicide')
plt.xticks(rotation=45)

plt.show()

# %%
ca=cause.groupby(by=['Type','Gender'],as_index=False)[["Total"]].sum().sort_values('Total',ascending=False)
ca.style.background_gradient(subset='Total',cmap='Reds')
# Out:
# <style type="text/css">
# #T_da2ff_row0_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_da2ff_row1_col2 {
#   background-color: #c5171c;
#   color: #f1f1f1;
# }
# #T_da2ff_row2_col2 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_da2ff_row3_col2 {
#   background-color: #eb372a;
#   color: #f1f1f1;
# }
# #T_da2ff_row4_col2 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_da2ff_row5_col2 {
#   background-color: #fc9474;
#   color: #000000;
# }
# #T_da2ff_row6_col2 {
#   background-color: #fc9d7f;
#   color: #000000;
# }
# #T_da2ff_row7_col2 {
#   background-color: #fca183;
#   color: #000000;
# }
# #T_da2ff_row8_col2 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_da2ff_row9_col2 {
#   background-color: #fdd7c6;
#   color: #000000;
# }
# #T_da2ff_row10_col2 {
#   background-color: #fed9c9;
#   color: #000000;
# }
# #T_da2ff_row11_col2, #T_da2ff_row12_col2 {
#   background-color: #fedccd;
#   color: #000000;
# }
# ...

# %%
cause
plt.figure(figsize=(15,10))
sns.barplot(data=ca,x='Type',y='Total',hue='Gender')
plt.title('Gender Wise Causes of Suicide')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
mm=means.groupby(by=['Type','Gender'],as_index=False)[['Total']].sum().sort_values('Total',ascending=False)
mm.style.background_gradient(subset='Total',cmap='Reds')
# Out:
# <style type="text/css">
# #T_1c08a_row0_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_1c08a_row1_col2 {
#   background-color: #f34c37;
#   color: #f1f1f1;
# }
# #T_1c08a_row2_col2 {
#   background-color: #fb7252;
#   color: #f1f1f1;
# }
# #T_1c08a_row3_col2 {
#   background-color: #fb7353;
#   color: #f1f1f1;
# }
# #T_1c08a_row4_col2 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_1c08a_row5_col2 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_1c08a_row6_col2, #T_1c08a_row7_col2 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_1c08a_row8_col2 {
#   background-color: #fdcebb;
#   color: #000000;
# }
# #T_1c08a_row9_col2 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_1c08a_row10_col2 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_1c08a_row11_col2 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_1c08a_row12_col2 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# ...

# %%
plt.figure(figsize=(15,10))
sns.barplot(data=mm, x='Type',y='Total',hue='Gender')
plt.title('Gender Wise mean Adopted to Commit Suicide')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
pp=profession.groupby(by=['Type','Gender'],as_index=False)[['Total']].sum().sort_values('Total',ascending=False)
pp.style.background_gradient(subset='Total',cmap='Reds')
# Out:
# <style type="text/css">
# #T_67590_row0_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_67590_row1_col2 {
#   background-color: #bd151a;
#   color: #f1f1f1;
# }
# #T_67590_row2_col2 {
#   background-color: #fb7151;
#   color: #f1f1f1;
# }
# #T_67590_row3_col2 {
#   background-color: #fca78b;
#   color: #000000;
# }
# #T_67590_row4_col2 {
#   background-color: #fcb499;
#   color: #000000;
# }
# #T_67590_row5_col2 {
#   background-color: #fcb79c;
#   color: #000000;
# }
# #T_67590_row6_col2 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_67590_row7_col2 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_67590_row8_col2 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_67590_row9_col2 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_67590_row10_col2 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_67590_row11_col2 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_67590_row12_col2 {
# ...

# %%
plt.figure(figsize=(13,6))

sns.barplot(data=pp, x='Type',y='Total',hue='Gender')
plt.title('Gender wise profession of the people committed Suicide')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
ss=social.groupby(by=['Type','Gender'],as_index=False)[['Total']].sum().sort_values('Total',ascending=False)
ss.style.background_gradient(subset='Total',cmap='Reds')
# Out:
# <style type="text/css">
# #T_c0d69_row0_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_c0d69_row1_col2 {
#   background-color: #f85f43;
#   color: #f1f1f1;
# }
# #T_c0d69_row2_col2 {
#   background-color: #fcab8f;
#   color: #000000;
# }
# #T_c0d69_row3_col2 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_c0d69_row4_col2 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_c0d69_row5_col2 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_c0d69_row6_col2 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_c0d69_row7_col2 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_c0d69_row8_col2, #T_c0d69_row9_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_c0d69">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0d69_level0_col0" class="col_heading level0 col0" >Type</th>
# ...

# %%
plt.figure(figsize=(13,6))
sns.barplot(data=ss,x='Type',y='Total',hue='Gender')
plt.title('Gender wise social status of the people who committed suicide')
plt.tight_layout()
plt.show()

# %%
age=cause.groupby(by='Age_group',as_index=False)[['Total']].sum().sort_values('Total',ascending=True)
age.style.background_gradient(subset='Total',cmap='Reds')
# Out:
# <style type="text/css">
# #T_4708d_row0_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_4708d_row1_col1 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_4708d_row2_col1 {
#   background-color: #f6583e;
#   color: #f1f1f1;
# }
# #T_4708d_row3_col1 {
#   background-color: #7c0510;
#   color: #f1f1f1;
# }
# #T_4708d_row4_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4708d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4708d_level0_col0" class="col_heading level0 col0" >Age_group</th>
#       <th id="T_4708d_level0_col1" class="col_heading level0 col1" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4708d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4708d_row0_col0" class="data row0 col0" >0-14</td>
#       <td id="T_4708d_row0_col1" class="data row0 col1" >32685</td>
#     </tr>
#     <tr>
# ...

# %%
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0']
plt.figure(figsize=(6,6))
plt.pie(x=age.Total,labels=age.Age_group,autopct='%.2f%%',colors=colors,wedgeprops={'edgecolor':'Grey'})
plt.legend(age.Age_group, title="Age Group", loc="lower left",bbox_to_anchor=(1, 0, 0.5, 1))
plt.title('Age Group wise suicide cases',fontweight='bold',size=15)
    
plt.axis('equal')
plt.show()

# %%
#cause
colors=['#ff9999', '#66b3ff']
plt.figure(figsize=(6,6))
gg=cause.groupby(by='Gender',as_index=False)[['Total']].sum()
plt.pie(x=gg.Total,labels=gg.Gender,colors=colors,autopct='%.1f%%',wedgeprops={'edgecolor':'grey'})
plt.legend(gg.Gender,title='Gender',loc='lower left')
plt.title('Percentage of Suicides Over The Years By Gender')
plt.show()

# %%
gg=cause.pivot_table(index='Year',columns='Gender',values='Total',aggfunc=sum)
gg.style.background_gradient(cmap='OrRd')
# Out:
# <style type="text/css">
# #T_47332_row0_col0 {
#   background-color: #fdd9a8;
#   color: #000000;
# }
# #T_47332_row0_col1, #T_47332_row2_col0 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_47332_row1_col0 {
#   background-color: #feefda;
#   color: #000000;
# }
# #T_47332_row1_col1 {
#   background-color: #fee6c4;
#   color: #000000;
# }
# #T_47332_row2_col1 {
#   background-color: #fedfb5;
#   color: #000000;
# }
# #T_47332_row3_col0 {
#   background-color: #fff0dc;
#   color: #000000;
# }
# #T_47332_row3_col1 {
#   background-color: #fdcb95;
#   color: #000000;
# }
# #T_47332_row4_col0 {
#   background-color: #fff1dd;
#   color: #000000;
# }
# #T_47332_row4_col1 {
#   background-color: #fdc992;
#   color: #000000;
# }
# #T_47332_row5_col0 {
#   background-color: #fdd49e;
#   color: #000000;
# }
# #T_47332_row5_col1 {
#   background-color: #fda56f;
#   color: #000000;
# }
# #T_47332_row6_col0 {
#   background-color: #fdb982;
#   color: #000000;
# }
# ...

# %%
plt.figure(figsize=(8,6))
plt.plot(gg.index,gg.Female,marker='o')
plt.plot(gg.index,gg.Male,marker='o')
plt.title('Gender wise suicide recorder per year',fontweight='bold',style='italic')
plt.legend(['Female','Male'])
plt.xlabel('Years',style='italic')
plt.ylabel('Suicide Recorded',style='italic')
for y,f in zip(gg.index,gg.Female):
    plt.text(y,f+1500,f,size=8)
for y,m in zip(gg.index,gg.Male):
    plt.text(y,m+1500,m,size=8)
plt.show()

# %%
yr=cause.pivot_table(index='State',columns=['Year','Gender'],values='Total',aggfunc=sum)
yr.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_26592_row0_col0, #T_26592_row0_col1, #T_26592_row0_col2, #T_26592_row0_col3, #T_26592_row0_col7, #T_26592_row0_col8, #T_26592_row0_col9, #T_26592_row0_col11, #T_26592_row0_col12, #T_26592_row0_col13, #T_26592_row0_col15, #T_26592_row0_col17, #T_26592_row0_col19, #T_26592_row0_col21, #T_26592_row2_col1, #T_26592_row2_col11, #T_26592_row2_col13, #T_26592_row2_col19, #T_26592_row2_col21, #T_26592_row2_col23, #T_26592_row14_col0, #T_26592_row14_col1, #T_26592_row14_col3, #T_26592_row14_col6, #T_26592_row14_col19, #T_26592_row22_col21, #T_26592_row22_col23, #T_26592_row29_col11, #T_26592_row29_col13, #T_26592_row29_col14, #T_26592_row29_col20, #T_26592_row29_col21, #T_26592_row29_col23, #T_26592_row33_col15 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# ...

# %%
cause.head(2)
# Out:
#            State  Year Type_code                                     Type  \
# 0  A & N Islands  2001    Causes                       Illness (Aids/STD)
# 1  A & N Islands  2001    Causes  Bankruptcy or Sudden change in Economic
#
#    Gender Age_group  Total
# 0  Female      0-14      0
# 1  Female      0-14      0

# %%
ag=cause.pivot_table(index='Year',columns=['Age_group'],values='Total',aggfunc=sum)
ag.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_1ebd5_row0_col0 {
#   background-color: #ac1117;
#   color: #f1f1f1;
# }
# #T_1ebd5_row0_col1, #T_1ebd5_row0_col2, #T_1ebd5_row0_col3, #T_1ebd5_row0_col4, #T_1ebd5_row11_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_1ebd5_row1_col0 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_1ebd5_row1_col1 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_1ebd5_row1_col2 {
#   background-color: #fee3d7;
#   color: #000000;
# }
# #T_1ebd5_row1_col3 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_1ebd5_row1_col4 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_1ebd5_row2_col0, #T_1ebd5_row5_col3 {
#   background-color: #fca486;
#   color: #000000;
# }
# #T_1ebd5_row2_col1 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_1ebd5_row2_col2 {
#   background-color: #ffece3;
#   color: #000000;
# }
# #T_1ebd5_row2_col3 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# ...

# %%
plt.figure(figsize=(12,6))
plt.plot(ag.index,ag['0-14'],marker='o',markersize=5)
plt.plot(ag.index,ag['15-29'],marker='o',markersize=5)
plt.plot(ag.index,ag['30-44'],marker='o',markersize=5)
plt.plot(ag.index,ag['45-59'],marker='o',markersize=5)
plt.plot(ag.index,ag['60+'],marker='o',markersize=5)
plt.legend(['0-14','15-29','30-44','45-59','60+'])
plt.title('Age group wise suicide cases recorded per year',fontweight='bold',style='italic')
plt.xlabel('Suicides Recorded',style='italic')
plt.ylabel('Year',style='italic')
for y,a in zip(ag.index,ag['0-14']):
    plt.text(y,a+700,a,size=9)
for y,a in zip(ag.index,ag['15-29']):
    plt.text(y,a+700,a,size=9)
for y,a in zip(ag.index,ag['30-44']):
    plt.text(y,a-1100,a,size=9)
for y,a in zip(ag.index,ag['45-59']):
    plt.text(y,a+700,a,size=9)
for y,a in zip(ag.index,ag['60+']):
    plt.text(y,a+700,a,size=9)  
plt.xticks(range(2002,2013,1),size=9)


plt.show()

# %%
st=cause.pivot_table(index=['Age_group','Gender'],columns=['State'],values='Total',aggfunc=sum)
st.style.background_gradient(cmap='Reds',axis=1)
# Out:
# <style type="text/css">
# #T_68555_row0_col0, #T_68555_row0_col10, #T_68555_row3_col29, #T_68555_row4_col10, #T_68555_row5_col14, #T_68555_row8_col27, #T_68555_row8_col29, #T_68555_row9_col10 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_68555_row0_col1, #T_68555_row3_col34 {
#   background-color: #c9181d;
#   color: #f1f1f1;
# }
# #T_68555_row0_col2, #T_68555_row0_col14, #T_68555_row0_col29, #T_68555_row1_col0, #T_68555_row1_col2, #T_68555_row1_col10, #T_68555_row1_col14, #T_68555_row1_col22, #T_68555_row1_col23, #T_68555_row1_col26, #T_68555_row2_col0, #T_68555_row2_col29, #T_68555_row3_col0, #T_68555_row3_col2, #T_68555_row3_col22, #T_68555_row3_col23, #T_68555_row4_col29, #T_68555_row5_col2, #T_68555_row5_col29, #T_68555_row6_col10, #T_68555_row6_col29, #T_68555_row6_col33, #T_68555_row7_col0, #T_68555_row7_col14, #T_68555_row7_col29, #T_68555_row8_col14, #T_68555_row9_col0 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# ...
